# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/home/hammadali08/Videos/CSV file/polynomial_regression_data.csv")
data
# Out:
#             X           Y
# 0  -10.000000 -616.797383
# 1   -9.797980 -647.095965
# 2   -9.595960 -581.633631
# 3   -9.393939 -483.330719
# 4   -9.191919 -468.115738
# ..        ...         ...
# 95   9.191919  268.856782
# 96   9.393939  252.915991
# 97   9.595960  361.534293
# 98   9.797980  299.447798
# 99  10.000000  335.099468
#
# [100 rows x 2 columns]

# %%
plt.scatter(data['X'],data['Y'])
plt.show()

# %%
x=data[['X']]
y=data['Y']

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3)

# %%
poly.fit(x)
# Out:
# PolynomialFeatures(degree=3)

# %%
x=poly.transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=45)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9741577004662183

# %%
prd=lr.predict(x)

# %%
plt.scatter(data['X'],data['Y'])
plt.plot(data['X'],prd,color='green')
plt.title('Polynomial Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
test=poly.transform([[-8.989899]])
# Out:
# /home/hammadali08/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
lr.predict(test)
# Out:
# array([-494.40573893])
