# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/home/hammadali08/Vidoes/CSV file/cardata.csv")
data.head()
# Out:
#   Car_Name  Year  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     ritz  2014           5.59       27000    Petrol      Dealer
# 1      sx4  2013           9.54       43000    Diesel      Dealer
# 2     ciaz  2017           9.85        6900    Petrol      Dealer
# 3  wagon r  2011           4.15        5200    Petrol      Dealer
# 4    swift  2014           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Selling_Price
# 0       Manual      0           3.35
# 1       Manual      0           4.75
# 2       Manual      0           7.25
# 3       Manual      0           2.85
# 4       Manual      0           4.60

# %%
plt.scatter(data['Present_Price'],data['Selling_Price'])

# %%
plt.scatter(data['Kms_Driven'],data['Selling_Price'])

# %%
sns.pairplot(data)

# %%
sns.heatmap(data[['Selling_Price','Present_Price','Kms_Driven']].corr(),annot=True)
plt.show()

# %%
x=data[['Present_Price','Kms_Driven']]
y=data['Selling_Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.32,random_state=70)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[9.54,43000]])
# Out:
# /home/hammadali08/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.49422982])

# %%
lr.score(x_test,y_test)
# Out:
# 0.8414176697805072

# %%
lr.score(x_train,y_train)
# Out:
# 0.7786678675390201
