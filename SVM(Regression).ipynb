# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/home/hammadali08/Vidoes/CSV file/Salary Data.csv")
data.drop(columns=['Gender','Education Level','Job Title'],inplace=True)
data
# Out:
#       Age  Years of Experience    Salary
# 0    32.0                  5.0   90000.0
# 1    28.0                  3.0   65000.0
# 2    45.0                 15.0  150000.0
# 3    36.0                  7.0   60000.0
# 4    52.0                 20.0  200000.0
# ..    ...                  ...       ...
# 370  35.0                  8.0   85000.0
# 371  43.0                 19.0  170000.0
# 372  29.0                  2.0   40000.0
# 373  34.0                  7.0   90000.0
# 374  44.0                 15.0  150000.0
#
# [375 rows x 3 columns]

# %%
data.fillna(data.mean(),inplace=True)
data['Salary']=pd.DataFrame(data['Salary'].astype('int64'))

# %%
sns.scatterplot(x="Years of Experience",y="Age",hue="Salary",data=data)
plt.show()

# %%
x=data.iloc[:,:-1]
y=data['Salary']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=50)

# %%
from sklearn.svm import SVR

# %%
sv=SVR(kernel='linear')

# %%
sv.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
sv.score(x_test,y_test)
# Out:
# 0.5975665789487632

# %% [markdown]
# Just to check

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.8066373479088313
