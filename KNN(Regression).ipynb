# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/home/hammadali08/Vidoes/CSV file/Salary Data.csv")
data.drop(columns=['Gender','Education Level','Job Title'],inplace=True)
data
# Out:
#       Age  Years of Experience    Salary
# 0    32.0                  5.0   90000.0
# 1    28.0                  3.0   65000.0
# 2    45.0                 15.0  150000.0
# 3    36.0                  7.0   60000.0
# 4    52.0                 20.0  200000.0
# ..    ...                  ...       ...
# 370  35.0                  8.0   85000.0
# 371  43.0                 19.0  170000.0
# 372  29.0                  2.0   40000.0
# 373  34.0                  7.0   90000.0
# 374  44.0                 15.0  150000.0
#
# [375 rows x 3 columns]

# %%
data.fillna(data.mean(),inplace=True)
data['Salary'].astype("int64")
# Out:
# 0       90000
# 1       65000
# 2      150000
# 3       60000
# 4      200000
#         ...
# 370     85000
# 371    170000
# 372     40000
# 373     90000
# 374    150000
# Name: Salary, Length: 375, dtype: int64

# %%
sns.scatterplot(x='Age',y='Years of Experience',data=data,hue='Salary')
plt.show()

# %%
x=data.iloc[:,:-1]
y=data['Salary']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knr=KNeighborsRegressor(n_neighbors=4)

# %%
knr.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
knr.score(x_test,y_test),knr.score(x_train,y_train)
# Out:
# (0.8734821430114477, 0.9094930498302306)

# %%
for i in range(1,20):
    knr2=KNeighborsRegressor(n_neighbors=i)
    knr2.fit(x_train,y_train)
    print(i,knr2.score(x_test,y_test),knr2.score(x_train,y_train))
# Out:
# 1 0.8195744445519778 0.9075733768190678
# 2 0.8432931077092176 0.9190705228480707
# 3 0.8638738553461728 0.9174665734919766
# 4 0.8734821430114477 0.9094930498302306
# 5 0.8816359627535291 0.9020920715909747
# 6 0.8772709703994904 0.8980425152426491
# 7 0.882936578795389 0.8976971938566374
# 8 0.8858353213247916 0.893414010999274
# 9 0.8867437733697278 0.8943032074212476
# 10 0.88332266954223 0.8917616403608462
# 11 0.8838453951004741 0.8926649285975085
# 12 0.8824107282460514 0.8914467828497148
# 13 0.8827927480644482 0.8908787438459685
# 14 0.8831577207040583 0.889050189487782
# 15 0.8810241066114323 0.8874202585331915
# 16 0.8825667408919275 0.8875051521217467
# 17 0.8837802993059145 0.8867144018070814
# 18 0.8829415334080246 0.8865734802441276
# 19 0.8835215136450919 0.8865507504131432
