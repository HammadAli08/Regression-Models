# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv("/home/hammadali08/Vidoes/CSV file/Salary Data.csv")
data.drop(columns=['Gender','Education Level','Job Title'],inplace=True)
data
# Out:
#       Age  Years of Experience    Salary
# 0    32.0                  5.0   90000.0
# 1    28.0                  3.0   65000.0
# 2    45.0                 15.0  150000.0
# 3    36.0                  7.0   60000.0
# 4    52.0                 20.0  200000.0
# ..    ...                  ...       ...
# 370  35.0                  8.0   85000.0
# 371  43.0                 19.0  170000.0
# 372  29.0                  2.0   40000.0
# 373  34.0                  7.0   90000.0
# 374  44.0                 15.0  150000.0
#
# [375 rows x 3 columns]

# %%
data.fillna(data.mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Age                    0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
sns.pairplot(data)
plt.show()

# %%
x=data.iloc[:,:-1]
y=data['Salary']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree

# %%
dtc=DecisionTreeRegressor(max_depth=4)

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=4)

# %%
dtc.score(x_test,y_test),dtc.score(x_train,y_train)
# Out:
# (0.8823119424399078, 0.9018525201180922)

# %% [markdown]
# It is Overfitted

# %%
plt.figure(figsize=(15,10))
plot_tree(dtc)
plt.show()

# %%
for i in range(1,10):
    dtc1=DecisionTreeRegressor(max_depth=i)
    dtc1.fit(x_train,y_train)
    print(i,dtc1.score(x_test,y_test),dtc1.score(x_train,y_train))
# Out:
# 1 0.6103472312540872 0.6677080347473552
# 2 0.8391744247174009 0.8453252943535273
# 3 0.8614382244133624 0.8815991601937806
# 4 0.8823119424399078 0.9018525201180922
# 5 0.8663506140056524 0.9171569638691068
# 6 0.8611601169168159 0.9214851580616193
# 7 0.8579181538329256 0.9279096262447797
# 8 0.8564112421517797 0.9319493404335296
# 9 0.8457984056688549 0.9355304595263133

# %%
dtc1=DecisionTreeRegressor(max_depth=4)

# %%
dtc1.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=4)

# %%
dtc1.score(x_test,y_test),dtc1.score(x_train,y_train)
# Out:
# (0.8823119424399078, 0.9018525201180922)
